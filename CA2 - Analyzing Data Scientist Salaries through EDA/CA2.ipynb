# %% [markdown]
# ### Ali Darabi - 810100264
# ### Hesam Ramezanian - 810100248

# %% [markdown]
# # Data Science - Assignment 2

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from forex_python.converter import CurrencyRates

# %% [markdown]
# # Task 1:

# %% [markdown]
# ## Q1:

# %%
dataFrameTaskOne = pd.read_csv("Task1.csv")
initDFTaskOne = dataFrameTaskOne.copy()

# %%
dataFrameTaskOne
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
dataFrameTaskOne.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %% [markdown]
# <font color='red'>
#
# The info() method provides a concise summary of a Pandas DataFrame, including the number of entries, the data types of each column, and the amount of memory used. It's useful for identifying any missing values or potential data type issues.
#
# </font>

# %%
dataFrameTaskOne.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# <font color='red'>
#
# The head() method is used to peek at the initial rows of the data in a Pandas DataFrame. By default, it returns the first 5 rows.
#
# </font>

# %%
dataFrameTaskOne.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %% [markdown]
# <font color='red'>
#
# The tail() method is used to peek at the final rows of the data in a Pandas DataFrame. By default, it returns the last 5 rows.
#
# </font>

# %%
dataFrameTaskOne.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# <font color='red'>
#
# The describe() method returns a statistical summary of the data in the DataFrame.
#
# If the DataFrame contains numerical data, the description includes the following information for each column:
#
# - count: The number of non-empty values.
# - mean: The average (mean) value.
# - std: The standard deviation.
# - min: The minimum value.
# - 25%: The 25th percentile.
# - 50%: The 50th percentile (median).
# - 75%: The 75th percentile.
# - max: The maximum value.
#
# </font>

# %% [markdown]
# ## Q2:

# %%
dataFrameTaskOne.dtypes
# Out:
# survived         int64
# pclass           int64
# sex             object
# age            float64
# sibsp            int64
# parch            int64
# fare           float64
# embarked        object
# class           object
# who             object
# adult_male        bool
# deck            object
# embark_town     object
# alive           object
# alone             bool
# dtype: object

# %%
dataFrameTaskOne["sex"] = dataFrameTaskOne["sex"].str.lower()
sexMap = {"male": 1, "female": 0}
dataFrameTaskOne["sex"] = dataFrameTaskOne["sex"].map(sexMap)

# %%
dataFrameTaskOne["age"] = dataFrameTaskOne["age"].replace([np.nan], -1)
dataFrameTaskOne["age"] = dataFrameTaskOne["age"].astype(int)

# %%
embarkedMap = {'S': 1, 'C': 2, 'Q': 3}
dataFrameTaskOne["embarked"] = dataFrameTaskOne["embarked"].map(embarkedMap)
dataFrameTaskOne["embarked"] = dataFrameTaskOne["embarked"].fillna(-1)
dataFrameTaskOne["embarked"] = dataFrameTaskOne["embarked"].astype(int)

# %%
classMap = {"First": 1, "Second": 2, "Third": 3}
dataFrameTaskOne["class"] = dataFrameTaskOne["class"].map(classMap)

# %%
whoMap = {"man": 1, "woman": 2, "child": 3}
dataFrameTaskOne["who"] = dataFrameTaskOne["who"].map(whoMap)

# %%
dataFrameTaskOne["adult_male"] = dataFrameTaskOne["adult_male"].astype(int)

# %%
deckMap = {'A': 1, 'B': 2, 'C': 3, 'D': 4, 'E': 5, 'F': 6, 'G': 7}
dataFrameTaskOne["deck"] = dataFrameTaskOne["deck"].map(deckMap)
dataFrameTaskOne["deck"] = dataFrameTaskOne["deck"].fillna(-1)
dataFrameTaskOne["deck"] = dataFrameTaskOne["deck"].astype(int)

# %%
embarkTownMap = {"Southampton": 1, "Cherbourg": 2, "Queenstown": 3}
dataFrameTaskOne["embark_town"] = dataFrameTaskOne["embark_town"].map(embarkTownMap)
dataFrameTaskOne["embark_town"] = dataFrameTaskOne["embark_town"].fillna(-1)
dataFrameTaskOne["embark_town"] = dataFrameTaskOne["embark_town"].astype(int)

# %%
aliveMap = {"yes": 1, "no": 0}
dataFrameTaskOne["alive"] = dataFrameTaskOne["alive"].map(aliveMap)

# %%
dataFrameTaskOne["alone"] = dataFrameTaskOne["alone"].astype(int)

# %% [markdown]
# <font color='red'>
#
# We used a labeling method to convert non-numerical columns to numerical ones and replaced NaN values (missing values) with -1. This approach allows us to easily identify missing values in the next parts of the analysis.
#
# </font>

# %%
dataFrameTaskOne.dtypes
# Out:
# survived         int64
# pclass           int64
# sex              int64
# age              int32
# sibsp            int64
# parch            int64
# fare           float64
# embarked         int32
# class            int64
# who              int64
# adult_male       int32
# deck             int32
# embark_town      int32
# alive            int64
# alone            int32
# dtype: object

# %% [markdown]
# ## Q3:

# %%
numericalCols = dataFrameTaskOne.select_dtypes(include=['float64', 'int64', 'int32']).columns

corrMatrix = dataFrameTaskOne[numericalCols].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corrMatrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# ## Q4:

# %%
print("Columns Before Removal:")
print(list(dataFrameTaskOne.columns))
# Out:
# Columns Before Removal:
# ['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare', 'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town', 'alive', 'alone']

# %%
colsForRemove = set()
for i in range(len(corrMatrix.columns)):
    for j in range(i + 1, len(corrMatrix.columns)):
        if abs(corrMatrix.iloc[i, j]) == 1:
            selectedCol = corrMatrix.columns[j]
            colsForRemove.add(selectedCol)

print("Columns selected to be removed:")
for col in colsForRemove:
    print(col)

dataFrameTaskOne = dataFrameTaskOne.drop(colsForRemove, axis=1)
# Out:
# Columns selected to be removed:
# alive
# class
# embark_town

# %%
print("Columns After Removal:")
print(list(dataFrameTaskOne.columns))
# Out:
# Columns After Removal:
# ['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare', 'embarked', 'who', 'adult_male', 'deck', 'alone']

# %% [markdown]
# ## Q5:

# %%
survivedPassengers = dataFrameTaskOne[dataFrameTaskOne["survived"] == 1]
numSurvived = survivedPassengers.shape[0]
print("Number of passengers who survived the disaster:", numSurvived)
# Out:
# Number of passengers who survived the disaster: 342

# %% [markdown]
# ## Q6:

# %%
femaleOver30 = dataFrameTaskOne[(dataFrameTaskOne["sex"] == 0) & (dataFrameTaskOne["age"] > 30)]
femaleOver30
# Out:
#      survived  pclass  sex  age  sibsp  parch     fare  embarked  who  \
# 1           1       1    0   38      1      0  71.2833         2    2
# 3           1       1    0   35      1      0  53.1000         1    2
# 11          1       1    0   58      0      0  26.5500         1    2
# 15          1       2    0   55      0      0  16.0000         1    2
# 18          0       3    0   31      1      0  18.0000         1    2
# ..        ...     ...  ...  ...    ...    ...      ...       ...  ...
# 862         1       1    0   48      0      0  25.9292         1    2
# 865         1       2    0   42      0      0  13.0000         1    2
# 871         1       1    0   47      1      1  52.5542         1    2
# 879         1       1    0   56      0      1  83.1583         2    2
# 885         0       3    0   39      0      5  29.1250         3    2
#
#      adult_male  deck  alone
# 1             0     3      0
# 3             0     3      0
# 11            0     3      1
# ...

# %%
numFemaleOver30 = femaleOver30.shape[0]
print("Number of female passengers aged more than 30 years:", numFemaleOver30)
# Out:
# Number of female passengers aged more than 30 years: 102

# %% [markdown]
# ## Q7:

# %%
cherbourgPassengersFareGreater100 = dataFrameTaskOne[(dataFrameTaskOne["embarked"] == 2) & (dataFrameTaskOne["fare"] > 100)]
cherbourgPassengersFareGreater100
# Out:
#      survived  pclass  sex  age  sibsp  parch      fare  embarked  who  \
# 31          1       1    0   -1      1      0  146.5208         2    2
# 118         0       1    1   24      0      1  247.5208         2    1
# 195         1       1    0   58      0      0  146.5208         2    2
# 215         1       1    0   31      1      0  113.2750         2    2
# 258         1       1    0   35      0      0  512.3292         2    2
# 299         1       1    0   50      0      1  247.5208         2    2
# 306         1       1    0   -1      0      0  110.8833         2    2
# 307         1       1    0   17      1      0  108.9000         2    2
# 311         1       1    0   18      2      2  262.3750         2    2
# 319         1       1    0   40      1      1  134.5000         2    2
# 325         1       1    0   36      0      0  135.6333         2    2
# 337         1       1    0   41      0      0  134.5000         2    2
# ...

# %%
numCherbourgPassengersFareGreater100 = cherbourgPassengersFareGreater100.shape[0]
print("Number of passengers who embarked from Cherbourg and paid a fare greater than 100:", numCherbourgPassengersFareGreater100)
# Out:
# Number of passengers who embarked from Cherbourg and paid a fare greater than 100: 29

# %% [markdown]
# ## Q8:

# %%
columnsWithMissingValue = (dataFrameTaskOne == -1).sum() > 0
print("Columns with missing values:", columnsWithMissingValue[columnsWithMissingValue].index.tolist())
# Out:
# Columns with missing values: ['age', 'embarked', 'deck']

# %%
missingValuesCount = dataFrameTaskOne[dataFrameTaskOne == -1].count()
print("Count of missing values in columns:")
missingValuesCount
# Out:
# Count of missing values in columns:
# survived        0
# pclass          0
# sex             0
# age           177
# sibsp           0
# parch           0
# fare            0
# embarked        2
# who             0
# adult_male      0
# deck          688
# alone           0
# dtype: int64

# %% [markdown]
# #### For embarked column:
# We replace the missing values in the 'embarked' column with the most common value because there are only two missing values.

# %%
modeEmbarked = dataFrameTaskOne["embarked"].mode()[0]

dataFrameTaskOne["embarked"] = dataFrameTaskOne["embarked"].replace(-1, modeEmbarked)

# %% [markdown]
# #### For age column:
# First, we determined the age range for each age group (man, woman, and child). Then, we filled missing values with a random age selected from within the appropriate age ranges.

# %%
#We found these ranges according to the 'who' and 'age' columns:
ageRanges = {1: (16, 80), 2: (16, 63), 3: (1, 15)}

def fillAge(row):
    if row["age"] == -1:
        if row["who"] in ageRanges:
            minAge, maxAge = ageRanges[row["who"]]
            return np.random.randint(minAge, maxAge)
    else:
        return row["age"]
    

dataFrameTaskOne["age"] = dataFrameTaskOne.apply(fillAge, axis=1)

# %% [markdown]
# #### For deck column:

# %% [markdown]
# At first, we wanted to find a relationship between the 'pclass' and 'deck' columns because the 'deck' column had the highest correlation with the 'pclass' column. However, that approach did not go well. Therefore, we decided to fill the missing values in the 'deck' column with a random sample generated according to the non-missing values in the same column.

# %%
def printDataFrequencyOfDeck(pclass):
    classData = dataFrameTaskOne[dataFrameTaskOne["pclass"] == pclass]
    return classData["deck"].value_counts()

print("First Class:", printDataFrequencyOfDeck(1))
print("Second Class:", printDataFrequencyOfDeck(2))
print("Third Class:", printDataFrequencyOfDeck(3))
# Out:
# First Class: deck
#  3    59
#  2    47
# -1    41
#  4    29
#  5    25
#  1    15
# Name: count, dtype: int64
# Second Class: deck
# -1    168
#  6      8
#  4      4
#  5      4
# Name: count, dtype: int64
# Third Class: deck
# -1    479
#  6      5
#  7      4
#  5      3
# Name: count, dtype: int64

# %%
nonMissingDeck = dataFrameTaskOne["deck"][dataFrameTaskOne["deck"] != -1]

randomSample = nonMissingDeck.sample(n=len(dataFrameTaskOne[dataFrameTaskOne["deck"] == -1]), replace=True)

dataFrameTaskOne.loc[dataFrameTaskOne["deck"] == -1, "deck"] = randomSample.values

# %%
missingValuesCount = dataFrameTaskOne[dataFrameTaskOne == -1].count()
print("Count of missing values in columns:")
missingValuesCount
# Out:
# Count of missing values in columns:
# survived      0
# pclass        0
# sex           0
# age           0
# sibsp         0
# parch         0
# fare          0
# embarked      0
# who           0
# adult_male    0
# deck          0
# alone         0
# dtype: int64

# %% [markdown]
# ## Q9:

# %%
overallAverageAge = dataFrameTaskOne["age"].mean()
print(f"The overall average age of passengers is: {overallAverageAge:.2f}")

maleAverageAge = dataFrameTaskOne[dataFrameTaskOne["sex"] == 1]["age"].mean()
maleDiffFromAvg = maleAverageAge - overallAverageAge
print(f"The average age of male passengers is: {maleAverageAge:.2f} (difference from overall average: {maleDiffFromAvg:.2f})")

femaleAverageAge = dataFrameTaskOne[dataFrameTaskOne["sex"] == 0]["age"].mean()
femaleDiffFromAvg = femaleAverageAge - overallAverageAge
print(f"The average age of female passengers is: {femaleAverageAge:.2f} (difference from overall average: {femaleDiffFromAvg:.2f})")
# Out:
# The overall average age of passengers is: 32.87
# The average age of male passengers is: 34.65 (difference from overall average: 1.78)
# The average age of female passengers is: 29.60 (difference from overall average: -3.27)

# %% [markdown]
# ## Q10:

# %%
correlation = dataFrameTaskOne["fare"].corr(dataFrameTaskOne["survived"])
print("Correlation between fare and survival rate:", correlation)
# Out:
# Correlation between fare and survival rate: 0.2573065223849622

# %% [markdown]
# The output shows a weak positive correlation between fare paid and survival rate (correlation coefficient of 0.2573). This means that there is a slight tendency for passengers who paid higher fares to be more likely to survive. However, the correlation is weak, so it may not be statistically significant.Therefore, while there's a slight positive association, the data alone may not be strong enough to conclusively say that fare directly caused a higher chance of survival. Other factors likely played a significant role in determining who survived the shipwreck.

# %% [markdown]
# ## Q11:

# %%
survivalByClass = dataFrameTaskOne.groupby("pclass")["survived"].mean()

plt.bar(survivalByClass.index, survivalByClass.values, color='green')
plt.xlabel('Passenger Class')
plt.ylabel('Survival Rate')
plt.title('Survival Rate by Passenger Class')
plt.xticks(survivalByClass.index, labels=['First Class', 'Second Class', 'Third Class'])
plt.ylim(0, 1) 
plt.show()

# %% [markdown]
# The graph confirms that the survival rate was significantly higher for passengers in first class compared to second and third class passengers. This likely reflects the social hierarchy of the time, where first-class passengers were given priority when boarding the lifeboats.

# %% [markdown]
# ## Q12:

# %%
survivedPassengersAge = dataFrameTaskOne[dataFrameTaskOne["survived"] == 1]["age"]
notSurvivedPassengersAge = dataFrameTaskOne[dataFrameTaskOne["survived"] == 0]["age"]

plt.hist ([survivedPassengersAge, notSurvivedPassengersAge], bins = 30, color = ["green", "red"], label = ["Survived", "Not survived"])
plt.xlabel ("Age")
plt.ylabel ("Number of Passengers")
plt.title ("Age distribution of passengers")
plt.legend ()
plt.show ()

# %% [markdown]
# Both lines appear to show a similar distribution, with a peak around 20-30 years old. This suggests that there were more passengers in this age range overall, regardless of whether they survived or not.  However, it is also evident that there were more survivors in the younger age groups (below 20) and the older age groups (above 50) compared to those in their 20s-40s. This could be due to a number of factors, such as:
#
# Children and elderly receiving priority on lifeboats.
#
# Stronger individuals being more likely to survive in the water.

# %% [markdown]
# ## Q13:

# %%
survivedPassengers = dataFrameTaskOne[dataFrameTaskOne["survived"] == 1]
notSurvivedPassengers = dataFrameTaskOne[dataFrameTaskOne["survived"] == 0]

plt.scatter(survivedPassengers["age"], survivedPassengers["fare"], color="green", label="Survived")
plt.scatter(notSurvivedPassengers["age"], notSurvivedPassengers["fare"], color="red", label="Not Survived")
plt.xlabel("Age")
plt.ylabel("Fare Paid")
plt.title("Relationship between Age and Fare Paid")
plt.legend()
plt.show()

# %% [markdown]
# There's no clear linear trend between age and fare paid. Data points are scattered throughout the graph, indicating a weak correlation.
#
# Survival is not necessarily linked to age or fare paid. There are survivors and non-survivors across all age groups and fare ranges. However, there seems to be a slightly higher concentration of survivors in the younger age groups (below 20) and the older age groups (above 50) compared to those in their 20s-40s. This aligns with what we saw previously in the age distribution plot.

# %% [markdown]
# ## Q14:

# %%
pivot_table = pd.pivot_table(dataFrameTaskOne, values=['fare', 'survived'], index=['pclass', 'sex'], aggfunc={'fare': 'mean', 'survived': 'mean'})
pivot_table
# Out:
#                   fare  survived
# pclass sex
# 1      0    106.125798  0.968085
#        1     67.226127  0.368852
# 2      0     21.970121  0.921053
#        1     19.741782  0.157407
# 3      0     16.118810  0.500000
#        1     12.661633  0.135447

# %% [markdown]
# According to the table:
#
#
# We can possibly understand that the female survival rate is higher, and the first-class survival rate might also be higher.

# %% [markdown]
# ## Q15:

# %%
averageFareByClassSurvival = dataFrameTaskOne.groupby(['pclass', 'survived'])['fare'].mean().unstack()

averageFareByClassSurvival.plot(kind='bar', color=['red', 'green'])
plt.xlabel('Passenger Class')
plt.ylabel('Average Fare')
plt.title('Average Fare Paid by Passengers, Grouped by Class and Survival Status')
plt.xticks(rotation=0) 
plt.legend(['Not Survived', 'Survived'], loc='upper left')
plt.show()

# %% [markdown]
# The chart clearly demonstrates that passengers in the higher classes (1st and 2nd) paid significantly higher average fares compared to those in the lower 3rd class. Additionally, within each class, the green "Survived" bars are taller than the red "Not Survived" bars, indicating that passengers who paid higher fares were more likely to survive.

# %% [markdown]
# # Task 2:

# %%
dataFrameTaskTwo = pd.read_csv("task2.csv")

# %%
dataFrameTaskTwo
# Out:
#        Work_Year Experience_Level Employment_Type                  Job_Title  \
# 0           2024     Senior-Level       Full-Time                AI Engineer
# 1           2024     Senior-Level       Full-Time  Machine Learning Engineer
# 2           2024     Senior-Level       Full-Time  Machine Learning Engineer
# 3           2024     Senior-Level       Full-Time  Machine Learning Engineer
# 4           2024     Senior-Level       Full-Time  Machine Learning Engineer
# ...          ...              ...             ...                        ...
# 13967       2020     Senior-Level       Full-Time             Data Scientist
# 13968       2021        Mid-Level       Full-Time   Principal Data Scientist
# 13969       2020      Entry-Level       Full-Time             Data Scientist
# 13970       2020      Entry-Level        Contract      Business Data Analyst
# 13971       2021     Senior-Level       Full-Time       Data Science Manager
#
# ...

# %%
dataFrameTaskTwo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13972 entries, 0 to 13971
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Work_Year         13972 non-null  int64
#  1   Experience_Level  13972 non-null  object
#  2   Employment_Type   13972 non-null  object
#  3   Job_Title         13972 non-null  object
#  4   Salary            13972 non-null  int64
#  5   Salary_Currency   13972 non-null  object
#  6   Remote_Ratio      13972 non-null  int64
#  7   Company_Size      13972 non-null  object
# dtypes: int64(3), object(5)
# memory usage: 873.4+ KB

# %% [markdown]
# <span style="color:red">As You can see there is no missing value.</span>

# %%
dataFrameTaskTwo.describe()
# Out:
#           Work_Year        Salary  Remote_Ratio
# count  13972.000000  1.397200e+04  13972.000000
# mean    2023.085600  1.660011e+05     33.334526
# std        0.687612  3.661545e+05     46.682931
# min     2020.000000  1.400000e+04      0.000000
# 25%     2023.000000  1.040000e+05      0.000000
# 50%     2023.000000  1.422000e+05      0.000000
# 75%     2024.000000  1.880000e+05    100.000000
# max     2024.000000  3.040000e+07    100.000000

# %%
dataFrameTaskTwo = dataFrameTaskTwo.drop_duplicates(subset=None, keep='first', inplace=False)

# %%
dataFrameTaskTwo
# Out:
#        Work_Year Experience_Level Employment_Type                  Job_Title  \
# 0           2024     Senior-Level       Full-Time                AI Engineer
# 1           2024     Senior-Level       Full-Time  Machine Learning Engineer
# 2           2024     Senior-Level       Full-Time  Machine Learning Engineer
# 3           2024     Senior-Level       Full-Time  Machine Learning Engineer
# 4           2024     Senior-Level       Full-Time  Machine Learning Engineer
# ...          ...              ...             ...                        ...
# 13967       2020     Senior-Level       Full-Time             Data Scientist
# 13968       2021        Mid-Level       Full-Time   Principal Data Scientist
# 13969       2020      Entry-Level       Full-Time             Data Scientist
# 13970       2020      Entry-Level        Contract      Business Data Analyst
# 13971       2021     Senior-Level       Full-Time       Data Science Manager
#
# ...

# %% [markdown]
# <span style="color:red">After removing duplicates, the number of rows reduced from 13972 to 8407.</span>

# %%
dataFrameTaskTwo.loc[:, 'Company_Size'] = dataFrameTaskTwo['Company_Size'].replace('S', 'Small')

# %%
frequencyOfSalaryCurrency = dataFrameTaskTwo['Salary_Currency'].value_counts()
pd.DataFrame(frequencyOfSalaryCurrency)
# Out:
#                  count
# Salary_Currency
# USD               7499
# GBP                410
# EUR                339
# INR                 52
# CAD                 48
# AUD                 12
# PLN                  7
# CHF                  6
# SGD                  6
# JPY                  4
# BRL                  4
# DKK                  3
# HUF                  3
# TRY                  3
# NOK                  2
# THB                  2
# ZAR                  1
# HKD                  1
# ILS                  1
# PHP                  1
# NZD                  1
# MXN                  1
# CLP                  1

# %%
mask = frequencyOfSalaryCurrency[frequencyOfSalaryCurrency >= 10].index
dataFrameTaskTwo = dataFrameTaskTwo[dataFrameTaskTwo['Salary_Currency'].isin(mask)]

# %%
dataFrameTaskTwo['Salary_Currency'].unique()
# Out:
# array(['USD', 'EUR', 'GBP', 'CAD', 'AUD', 'INR'], dtype=object)

# %%
dataFrameTaskTwo
# Out:
#        Work_Year Experience_Level Employment_Type                  Job_Title  \
# 0           2024     Senior-Level       Full-Time                AI Engineer
# 1           2024     Senior-Level       Full-Time  Machine Learning Engineer
# 2           2024     Senior-Level       Full-Time  Machine Learning Engineer
# 3           2024     Senior-Level       Full-Time  Machine Learning Engineer
# 4           2024     Senior-Level       Full-Time  Machine Learning Engineer
# ...          ...              ...             ...                        ...
# 13967       2020     Senior-Level       Full-Time             Data Scientist
# 13968       2021        Mid-Level       Full-Time   Principal Data Scientist
# 13969       2020      Entry-Level       Full-Time             Data Scientist
# 13970       2020      Entry-Level        Contract      Business Data Analyst
# 13971       2021     Senior-Level       Full-Time       Data Science Manager
#
# ...

# %% [markdown]
# <span style="color:red">After removing currencies with a frequency of under 10, the number of rows reduced from 8407 to 8360.</span>

# %%
def ConvertToUsd(currencyRates,amount, currency):
    try:
        return currencyRates.convert(currency, 'USD', amount)
    except:
        return -1

# %%
currencyRates = CurrencyRates()
dataFrameTaskTwo.loc[:, 'Salary'] = dataFrameTaskTwo.apply(lambda row: ConvertToUsd(currencyRates, row['Salary'], row['Salary_Currency']), axis=1)
# Out:
# C:\Users\alida\AppData\Local\Temp\ipykernel_19416\1736354459.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 90000.        180500.         96200.        ... 105000.
#  100000.         84330.6500786]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dataFrameTaskTwo.loc[:, 'Salary'] = dataFrameTaskTwo.apply(lambda row: ConvertToUsd(currencyRates, row['Salary'], row['Salary_Currency']), axis=1)

# %%
dataFrameTaskTwo
# Out:
#        Work_Year Experience_Level Employment_Type                  Job_Title  \
# 0           2024     Senior-Level       Full-Time                AI Engineer
# 1           2024     Senior-Level       Full-Time  Machine Learning Engineer
# 2           2024     Senior-Level       Full-Time  Machine Learning Engineer
# 3           2024     Senior-Level       Full-Time  Machine Learning Engineer
# 4           2024     Senior-Level       Full-Time  Machine Learning Engineer
# ...          ...              ...             ...                        ...
# 13967       2020     Senior-Level       Full-Time             Data Scientist
# 13968       2021        Mid-Level       Full-Time   Principal Data Scientist
# 13969       2020      Entry-Level       Full-Time             Data Scientist
# 13970       2020      Entry-Level        Contract      Business Data Analyst
# 13971       2021     Senior-Level       Full-Time       Data Science Manager
#
# ...

# %% [markdown]
# <span style="color:red">We converted currencies other than USD to USD. In this process, if one of the conversion operations encountered an error, the value -1 is placed instead of the number. You can see the final result of the currency conversion, for example, row 13971 has been converted.</span>

# %%
dataFrameTaskTwo.loc[:, 'Salary'] = dataFrameTaskTwo['Salary'].round().astype(int)

# %%
dataFrameTaskTwo
# Out:
#        Work_Year Experience_Level Employment_Type                  Job_Title  \
# 0           2024     Senior-Level       Full-Time                AI Engineer
# 1           2024     Senior-Level       Full-Time  Machine Learning Engineer
# 2           2024     Senior-Level       Full-Time  Machine Learning Engineer
# 3           2024     Senior-Level       Full-Time  Machine Learning Engineer
# 4           2024     Senior-Level       Full-Time  Machine Learning Engineer
# ...          ...              ...             ...                        ...
# 13967       2020     Senior-Level       Full-Time             Data Scientist
# 13968       2021        Mid-Level       Full-Time   Principal Data Scientist
# 13969       2020      Entry-Level       Full-Time             Data Scientist
# 13970       2020      Entry-Level        Contract      Business Data Analyst
# 13971       2021     Senior-Level       Full-Time       Data Science Manager
#
# ...

# %% [markdown]
# <span style="color:red">Now, since all dollar data is round, we also round the converted data.</span>

# %%
jobTitleCounts = dataFrameTaskTwo['Job_Title'].value_counts()
display(pd.DataFrame(jobTitleCounts.head(10)))
# Out:
#                            count
# Job_Title
# Data Engineer               1584
# Data Scientist              1548
# Data Analyst                1141
# Machine Learning Engineer    797
# Analytics Engineer           315
# Research Scientist           265
# Data Architect               224
# Research Engineer            177
# Data Science                 140
# ML Engineer                  134

# %%
plt.figure(figsize=(20, 6))
jobTitleCounts.plot(kind='bar')
plt.title('Job Title Counts')
plt.xlabel('Job Title')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right', fontsize=7) 
plt.tight_layout()
plt.show()

# %% [markdown]
# <span style="color:red">At first, we show the ten most popular jobs in this dataset. Then, we created a chart to illustrate how the counts are distributed across these different jobs. As you can observe, a significant portion of the data is associated with a select few job titles. This might be because these job titles are more generic in nature.</span>

# %%
topSalaries = dataFrameTaskTwo.nlargest(10, 'Salary')[['Job_Title', 'Salary', 'Salary_Currency']]
topSalaries = topSalaries.reset_index(drop=True)
topSalaries
# Out:
#                     Job_Title    Salary Salary_Currency
# 0                AI Architect  800000.0             USD
# 1                Data Analyst  774000.0             USD
# 2          Analytics Engineer  750000.0             USD
# 3  Machine Learning Scientist  750000.0             USD
# 4                Data Analyst  750000.0             USD
# 5  Machine Learning Scientist  750000.0             USD
# 6   Machine Learning Engineer  750000.0             USD
# 7               Data Engineer  750000.0             USD
# 8              Data Scientist  750000.0             USD
# 9          Analytics Engineer  720000.0             USD

# %% [markdown]
# <span style="color:red">We have now displayed the top 10 people with the highest salaries. They all receive their salaries in US dollars.</span>

# %%
AvgSalaryByJob = dataFrameTaskTwo.groupby('Job_Title')['Salary'].mean().reset_index()
AvgSalaryByJob = AvgSalaryByJob.sort_values(by='Salary', ascending=False)
top10AvgSalaries = AvgSalaryByJob.head(10)
top10AvgSalaries = top10AvgSalaries.reset_index().drop("index",axis=1)
top10AvgSalaries
# Out:
#                         Job_Title         Salary
# 0   Analytics Engineering Manager  408808.000000
# 1          Data Science Tech Lead  375000.000000
# 2        Head of Machine Learning  299183.285714
# 3  Managing Director Data Science  280000.000000
# 4              AWS Data Architect  258000.000000
# 5            Cloud Data Architect  250000.000000
# 6                    AI Architect  248945.000000
# 7                 Prompt Engineer  213697.000000
# 8        Director of Data Science  212703.354839
# 9    Data Infrastructure Engineer  207332.812500

# %% [markdown]
# <span style="color:red">We have now displayed the 10 job titles with the highest average salaries.</span>

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=dataFrameTaskTwo, x='Salary', kde=True)
plt.title('Distribution of Salaries')
plt.show()

# %% [markdown]
# <span style="color:red">
#
# • The most common salary range is between $100,000 and $200,000 per year. This is because the tallest bar on the graph is in this range.
#
#
# • The salary distribution is skewed to the right. This means that there are more people making lower salaries than there are people making higher salaries.
#
# </span>

# %%
numricalDataFrame = dataFrameTaskTwo.copy()
numricalDataFrame
# Out:
#        Work_Year Experience_Level Employment_Type                  Job_Title  \
# 0           2024     Senior-Level       Full-Time                AI Engineer
# 1           2024     Senior-Level       Full-Time  Machine Learning Engineer
# 2           2024     Senior-Level       Full-Time  Machine Learning Engineer
# 3           2024     Senior-Level       Full-Time  Machine Learning Engineer
# 4           2024     Senior-Level       Full-Time  Machine Learning Engineer
# ...          ...              ...             ...                        ...
# 13967       2020     Senior-Level       Full-Time             Data Scientist
# 13968       2021        Mid-Level       Full-Time   Principal Data Scientist
# 13969       2020      Entry-Level       Full-Time             Data Scientist
# 13970       2020      Entry-Level        Contract      Business Data Analyst
# 13971       2021     Senior-Level       Full-Time       Data Science Manager
#
# ...

# %% [markdown]
# <span style="color:red">We now want to create a copy of this data so that we can convert its non-numerical data into numerical data, in order to plot a correlation matrix.</span>

# %%
numricalDataFrame = numricalDataFrame.drop("Salary_Currency",axis=1)
numricalDataFrame
# Out:
#        Work_Year Experience_Level Employment_Type                  Job_Title  \
# 0           2024     Senior-Level       Full-Time                AI Engineer
# 1           2024     Senior-Level       Full-Time  Machine Learning Engineer
# 2           2024     Senior-Level       Full-Time  Machine Learning Engineer
# 3           2024     Senior-Level       Full-Time  Machine Learning Engineer
# 4           2024     Senior-Level       Full-Time  Machine Learning Engineer
# ...          ...              ...             ...                        ...
# 13967       2020     Senior-Level       Full-Time             Data Scientist
# 13968       2021        Mid-Level       Full-Time   Principal Data Scientist
# 13969       2020      Entry-Level       Full-Time             Data Scientist
# 13970       2020      Entry-Level        Contract      Business Data Analyst
# 13971       2021     Senior-Level       Full-Time       Data Science Manager
#
#          Salary  Remote_Ratio Company_Size
# ...

# %% [markdown]
# <span style="color:red">This code removes the column named "Salary_Currency" from the DataFrame `numricalDataFrame`, because all currencies have been converted to US dollars.</span>

# %%
numricalDataFrame['Experience_Level'].unique()
# Out:
# array(['Senior-Level', 'Mid-Level', 'Entry-Level', 'Executive-Level'],
#       dtype=object)

# %%
experienceMapping = {
    'Executive-Level': 4,
    'Senior-Level': 3,
    'Mid-Level': 2,
    'Entry-Level': 1
}

numricalDataFrame['Experience_Level'] = numricalDataFrame['Experience_Level'].map(experienceMapping)
numricalDataFrame
# Out:
#        Work_Year  Experience_Level Employment_Type                  Job_Title  \
# 0           2024                 3       Full-Time                AI Engineer
# 1           2024                 3       Full-Time  Machine Learning Engineer
# 2           2024                 3       Full-Time  Machine Learning Engineer
# 3           2024                 3       Full-Time  Machine Learning Engineer
# 4           2024                 3       Full-Time  Machine Learning Engineer
# ...          ...               ...             ...                        ...
# 13967       2020                 3       Full-Time             Data Scientist
# 13968       2021                 2       Full-Time   Principal Data Scientist
# 13969       2020                 1       Full-Time             Data Scientist
# 13970       2020                 1        Contract      Business Data Analyst
# 13971       2021                 3       Full-Time       Data Science Manager
#
# ...

# %% [markdown]
# <span style="color:red">This code maps categorical experience levels to numerical values in the DataFrame column 'Experience_Level'.</span>

# %%
len(numricalDataFrame['Job_Title'].unique())
# Out:
# 145

# %%
AvgSalaryByJob = AvgSalaryByJob.reset_index(drop=True)
AvgSalaryByJobRev = AvgSalaryByJob.iloc[::-1].reset_index(drop=True)
AvgSalaryByJobRev
# Out:
#                           Job_Title         Salary
# 0                 Data Analyst Lead   18000.000000
# 1          Principal Data Architect   36142.000000
# 2           Compliance Data Analyst   45000.000000
# 3                   Insight Analyst   46969.833333
# 4              Admin & Data Analyst   50306.000000
# ..                              ...            ...
# 140              AWS Data Architect  258000.000000
# 141  Managing Director Data Science  280000.000000
# 142        Head of Machine Learning  299183.285714
# 143          Data Science Tech Lead  375000.000000
# 144   Analytics Engineering Manager  408808.000000
#
# [145 rows x 2 columns]

# %%
jobTitleIndices = {title: index for index, title in enumerate(AvgSalaryByJobRev['Job_Title'])}

numricalDataFrame['Job_Title'] = numricalDataFrame['Job_Title'].replace(jobTitleIndices)

numricalDataFrame
# Out:
# C:\Users\alida\AppData\Local\Temp\ipykernel_19416\3866031463.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numricalDataFrame['Job_Title'] = numricalDataFrame['Job_Title'].replace(jobTitleIndices)
#        Work_Year  Experience_Level Employment_Type  Job_Title    Salary  \
# 0           2024                 3       Full-Time        112   90000.0
# 1           2024                 3       Full-Time        122  180500.0
# 2           2024                 3       Full-Time        122   96200.0
# 3           2024                 3       Full-Time        122  235000.0
# 4           2024                 3       Full-Time        122  175000.0
# ...          ...               ...             ...        ...       ...
# ...

# %% [markdown]
# <span style="color:red">
#
# - Counted the unique job titles
# - Sorted the average salaries by job title
# - Assigned numeric indices to the job titles in descending order of average salary
# - Replaced the job titles with the numeric indices in the main dataset
#
# </span>

# %%
numricalDataFrame['Company_Size'].unique()
# Out:
# array(['Large', 'Medium', 'Small'], dtype=object)

# %%
companySizeMapping = {
    'Large': 3,
    'Medium': 2,
    'Small': 1
}

numricalDataFrame['Company_Size'] = numricalDataFrame['Company_Size'].map(companySizeMapping)
numricalDataFrame
# Out:
#        Work_Year  Experience_Level Employment_Type  Job_Title    Salary  \
# 0           2024                 3       Full-Time        112   90000.0
# 1           2024                 3       Full-Time        122  180500.0
# 2           2024                 3       Full-Time        122   96200.0
# 3           2024                 3       Full-Time        122  235000.0
# 4           2024                 3       Full-Time        122  175000.0
# ...          ...               ...             ...        ...       ...
# 13967       2020                 3       Full-Time         98  412000.0
# 13968       2021                 2       Full-Time        129  151000.0
# 13969       2020                 1       Full-Time         98  105000.0
# 13970       2020                 1        Contract         20  100000.0
# 13971       2021                 3       Full-Time        120   84331.0
#
#        Remote_Ratio  Company_Size
# 0                 0             3
# ...

# %% [markdown]
# <span style="color:red">The code creates a dictionary `companySizeMapping` that maps the textual company sizes ('Large', 'Medium', 'Small') to numeric indices (3, 2, 1). It then uses the `map` function to apply this mapping to the `Company_Size` column in `numricalDataFrame`, replacing the textual values with their corresponding numeric indices.</span>

# %%
numricalDataFrame['Employment_Type'].unique()
# Out:
# array(['Full-Time', 'Contract', 'Part-Time', 'Freelance'], dtype=object)

# %%
employment_mapping = {
    'Full-Time': 1,
    'Contract': 2,
    'Part-Time': 3,
    'Freelance': 4
}

numricalDataFrame['Employment_Type'] = numricalDataFrame['Employment_Type'].map(employment_mapping)
numricalDataFrame
# Out:
#        Work_Year  Experience_Level  Employment_Type  Job_Title    Salary  \
# 0           2024                 3                1        112   90000.0
# 1           2024                 3                1        122  180500.0
# 2           2024                 3                1        122   96200.0
# 3           2024                 3                1        122  235000.0
# 4           2024                 3                1        122  175000.0
# ...          ...               ...              ...        ...       ...
# 13967       2020                 3                1         98  412000.0
# 13968       2021                 2                1        129  151000.0
# 13969       2020                 1                1         98  105000.0
# 13970       2020                 1                2         20  100000.0
# 13971       2021                 3                1        120   84331.0
#
#        Remote_Ratio  Company_Size
# 0                 0             3
# ...

# %% [markdown]
# <span style="color:red">The code creates a dictionary `employment_mapping` that maps textual employment types ('Full-Time', 'Contract', 'Part-Time', 'Freelance') to numeric indices (1, 2, 3, 4). It then uses the `map` function to apply this mapping to the `Employment_Type` column in `numricalDataFrame`, replacing the textual values with their corresponding numeric indices.</span>

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(numricalDataFrame.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# <span style="color:red">
# • Work_Year has a very weak correlation with all other variables. This means that the number of years of work experience has little to no effect on the other factors measured, such as salary, job title, or company size.
#
# • Experience_Level has a weak positive correlation with Salary and Job_Title. This suggests that there is a slight tendency for people with more experience to have higher salaries and hold higher job titles.
#
# • Employment_Type has a weak negative correlation with Salary. This could indicate that full-time employees tend to earn more than part-time, contract, or freelance workers. However, the correlation is weak, so more data would be needed to confirm this.
#
# • Job_Title has a moderate positive correlation with Salary. This is likely to be the strongest correlation in the matrix, because higher positions typically come with higher salaries.
#
# • Salary does not appear to have a strong correlation with Remote_Ratio or Company_Size. This means that there is no clear relationship between salary and whether a job is remote or the size of the company.
# </span>

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Experience_Level', y='Salary', data=dataFrameTaskTwo)
plt.title('Salary by Experience Level')
plt.show()

# %% [markdown]
# <span style="color:red">
#
# - Salary range: The salary range increases as the experience level goes up, which is expected. Entry-Level positions have the lowest salary range, while Executive-Level positions have the highest salary range.
# - Salary distribution: The box plot shows the distribution of salaries within each experience level. The box represents the interquartile range (IQR), where 50% of the data lies. The line inside the box is the median salary for that experience level.
# - Outliers: The plot indicates the presence of outliers, represented by individual dots, which are salaries that significantly deviate from the typical range for that experience level. There are several outliers for Mid-Level and Senior-Level positions, suggesting some individuals earn substantially higher or lower salaries than the majority within those experience levels.
# - Salary variability: The box size represents the variability in salaries. Executive-Level positions seem to have a wider salary range compared to other levels, indicating higher variability in compensation at that level. Entry-Level positions have the smallest box, suggesting less variability in salaries for those roles.
# - Median salaries: Based on the median lines within the boxes, the median salary appears to increase consistently from Entry-Level to Executive-Level positions, reflecting the expected trend of higher compensation with more experience.
# </span>

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='Company_Size', y='Salary', data=dataFrameTaskTwo)
plt.title('Salary by Company Size')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <span style="color:red">
#
# -  The medium-sized companies tend to pay the highest salaries compared to large and small companies.
#
# - Large companies offer higher salaries than small companies, but lower than medium-sized companies.
#
# - There is a significant difference in the salary levels between medium-sized companies and the other two categories (large and small).
#
# - The salaries paid by small companies appear to have a wider range or variation compared to large and medium-sized companies, as indicated by the longer error bar on the "Small" bar.
#
# </span>

# %%
plt.figure(figsize=(10, 6))
plt.scatter(numricalDataFrame['Work_Year'], numricalDataFrame['Salary'], alpha=0.5)
plt.title('Salary by Work Year')
plt.xlabel('Work Year')
plt.ylabel('Salary')
plt.xticks(range(int(numricalDataFrame['Work_Year'].min()), int(numricalDataFrame['Work_Year'].max()) + 1, 1)) 
plt.grid(True)
plt.show()

# %% [markdown]
# <span style="color:red">
#
# - The overall trend shows a steady increase in salaries from 2020 to 2024, indicating a general rise in compensation levels over the years.
#
# - There is a wider range or variation in salaries within each work year, as represented by the vertical lines extending from the data points. This variation could be due to factors such as job roles, industries, experience levels, or geographical locations.
#
# - The rate of increase in salaries appears to be relatively consistent from year to year, with no significant spikes or dips observed in the data.
#
# - While the trend line shows an upward trajectory, there are some data points that fall below the line, suggesting that not all individuals or positions experienced the same rate of salary growth within a given year.
#
# - The highest salaries and the widest variation in salaries are observed in the most recent year (2024), possibly indicating a continued demand for skilled professionals or a widening gap in compensation levels.
# </span>

# %%
df = pd.DataFrame(dataFrameTaskTwo)

for remoteRatio in  dataFrameTaskTwo['Remote_Ratio'].unique():
    filtered_df = df[df['Remote_Ratio'] == remoteRatio]
    count_by_year = filtered_df.groupby('Work_Year').size()
    plt.figure(figsize=(10, 6))
    sns.barplot(x=count_by_year.index, y=count_by_year.values, color='skyblue')
    plt.title(f'Count of {remoteRatio}% Remote Ratio by Work Year')
    plt.xlabel('Work Year')
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.grid(axis='y')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# <span style="color:red">
#
# - From Image 1, we can observe a significant increase in the count of employees with 0% remote work ratio (fully on-site) over the years, especially from 2022 to 2024. This could indicate a potential shift back towards more on-site or office-based work arrangements.
#
# - Image 2 shows an opposite trend, where the count of employees with a 100% remote work ratio (fully remote) peaked in 2023 but declined in 2024. This could suggest that while remote work may have been prevalent during certain periods, there is now a gradual return to more hybrid or on-site working models.
#
# -  Image 3, the count of employees with a 50% remote work ratio (hybrid model) seems to have remained relatively stable over the years, with a slight dip in 2024. This could mean that hybrid work arrangements have been a consistent practice, although there might be a slight shift towards either more on-site or fully remote models in the most recent year.
#
# - Collectively, the plots indicate a potential shift in work arrangements, with a resurgence of on-site work in 2024 after a period of increased remote work during 2022 and 2023. However, hybrid models still appear to be present, suggesting a mix of on-site and remote work arrangements.
#
# </span>

# %%
combDataFrame = numricalDataFrame.copy()
combDataFrame['New_Feature'] = 2 * combDataFrame['Company_Size'] * combDataFrame['Remote_Ratio'] / (combDataFrame['Company_Size'] + combDataFrame['Remote_Ratio'])
combDataFrame
# Out:
#        Work_Year  Experience_Level  Employment_Type  Job_Title    Salary  \
# 0           2024                 3                1        112   90000.0
# 1           2024                 3                1        122  180500.0
# 2           2024                 3                1        122   96200.0
# 3           2024                 3                1        122  235000.0
# 4           2024                 3                1        122  175000.0
# ...          ...               ...              ...        ...       ...
# 13967       2020                 3                1         98  412000.0
# 13968       2021                 2                1        129  151000.0
# 13969       2020                 1                1         98  105000.0
# 13970       2020                 1                2         20  100000.0
# 13971       2021                 3                1        120   84331.0
#
#        Remote_Ratio  Company_Size  New_Feature
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(combDataFrame.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# <span style="color:red">
#
# - The "New_Feature" has a strong positive correlation of 0.95 with the "Remote_Ratio" feature. This indicates that the new feature is heavily influenced by or derived from the "Remote_Ratio" feature, due to the harmonic average calculation involving "Remote_Ratio" and "Company_Size".
#
# - The "New_Feature" has a moderate positive correlation of 0.26 with "Company_Size". This suggests that while the new feature is influenced by "Company_Size" through the harmonic average calculation, the influence of "Remote_Ratio" is more dominant.
#
# - The "New_Feature" has a negative correlation of -0.28 with "Work_Year", indicating that as the work year increases, the value of the new feature tends to decrease. This could be related to potential changes in remote work ratios or company sizes over time
#
# </span>
